# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("true_car_listings.csv")
aux = pd.read_csv("true_car_listings.csv")
df.dtypes
# Out:
# Price       int64
# Year        int64
# Mileage     int64
# City       object
# State      object
# Vin        object
# Make       object
# Model      object
# dtype: object

# %%
q3 = df.groupby(["Make",'Model']).quantile(0.75)["Price"].reset_index(name='X')
q3
# Out:
#        Make                               Model          X
# 0        AM                             General   66499.50
# 1     Acura                         CLAutomatic    4995.00
# 2     Acura                            CLManual    5740.00
# 3     Acura                            CLType-S    5989.00
# 4     Acura                              ILX4dr   15490.00
# 5     Acura                          ILX5-Speed   18492.75
# 6     Acura                          ILX6-Speed   17999.50
# 7     Acura                       ILXAcuraWatch   22988.00
# 8     Acura                        ILXAutomatic   23995.00
# 9     Acura                           ILXHybrid   17146.00
# 10    Acura                          ILXPremium   26369.00
# 11    Acura                       ILXTechnology   27991.00
# 12    Acura                           IntegraGS    4523.75
# 13    Acura                           IntegraLS    3990.00
# 14    Acura                           IntegraRS    3997.00
# ...

# %%
df['Q3'] = q3["X"]
df['Q1'] = q1["Y"]
df["IQ"] = (df["Q3"]-df["Q1"])*1.5
df.dtypes
# Out:
# Price        int64
# Year         int64
# Mileage      int64
# City        object
# State       object
# Vin         object
# Make        object
# Model       object
# Q3         float64
# Q1         float64
# IQ         float64
# dtype: object

# %%
df["ls"] = df["Q3"]+df["IQ"]
df["lf"] = df["Q1"]-df["IQ"]
df
# Out:
#         Price  Year  Mileage               City State                Vin  \
# 0        8995  2014    35725            El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606   Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851            El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922            Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142             Lindon    UT  19UDE2F32GA001284
# 5        7989  2012   105246              Miami    FL  JH4CU2F83CC019895
# 6       14490  2014    34032          Greatneck    NY  JH4CU2F84EC002686
# 7       13995  2013    32384        West Jordan    UT  JH4CU2F64DC006203
# 8       10495  2013    57596          Waterbury    CT  19VDE2E50DE000234
# 9        9995  2013    63887            El Paso    TX  19VDE1F50DE010450
# 10      12921  2012    58550              Boise    ID  JH4CU2F44CC003220
# 11      12000  2013    40527   Long Island City    NY  19VDE1F38DE020867
# ...

# %%
df = df.drop(["Q3"], axis=1)
df = df.drop(["Q1"], axis=1)
df.dtypes
# Out:
# Price        int64
# Year         int64
# Mileage      int64
# City        object
# State       object
# Vin         object
# Make        object
# Model       object
# IQ         float64
# ls         float64
# lf         float64
# dtype: object

# %%
df.loc[(df.Price > df.ls)|(df.Price < df.lf)]
# Out:
#       Price  Year  Mileage              City State                Vin   Make  \
# 6     14490  2014    34032         Greatneck    NY  JH4CU2F84EC002686  Acura
# 16    14990  2015    23603          Freeport    NY  19VDE1F3XFE007606  Acura
# 18     9500  2011    68289           Arcadia    FL  JH4CU2F62BC007928  Acura
# 20    16994  2015    23946     St. Augustine    FL  19VDE1F32FE000651  Acura
# 41    14994  2014    22266           Seffner    FL  19VDE1F70EE006336  Acura
# 45    15965  2015    30091  Wappingers Falls    NY  19VDE1F3XFE005306  Acura
# 46     8995  2007    53525  South Hackensack    NJ  JH4CL96807C008922  Acura
# 47    13987  2011    44330      Indianapolis    IN  JH4CU2F62BC018296  Acura
# 50    14994  2014    34599  Wappingers Falls    NY  19VDE1F32EE011275  Acura
# 58    16499  2014    25068   West Palm Beach    FL  JH4CU2F81EC004640  Acura
# 61    13473  2010    29875   West Palm Beach    FL  JH4CU2F69AC026376  Acura
# ...

# %%
df = df.drop(df[(df.Price > df.ls)|(df.Price < df.lf)].index)
df
# Out:
#         Price  Year  Mileage               City State                Vin  \
# 2        8995  2013    48851            El Paso    TX  19VDE2E52DE000025
# 28      16000  2015    30881           Pasadena    CA  19VDE1F34FE008878
# 29      17419  2015    15390       Indianapolis    IN  19VDE1F37FE002458
# 31      14999  2015    28326              Miami    FL  19VDE1F30FE000177
# 32      17000  2015    24671             Tucson    AZ  19VDE1F33FE009911
# 33      12500  2010    50821    Fort Lauderdale    FL  JH4CU2F68AC029706
# 43      13699  2012    39342         Bellflower    CA  JH4CU2F45CC008409
# 44      12933  2011    54050         Fort Myers    FL  JH4CU2F66BC009536
# 49      16990  2014    16848         Clearwater    FL  19VDE1F36EE005995
# 52      18500  2015    18283        San Antonio    TX  19VDE1F3XFE006097
# 55       9995  2006    62983              Omaha    NE  JH4CL96886C009248
# 56      13799  2013    31055            Stanton    CA  19VDE1F38DE021159
# ...

# %%
aux
# Out:
#         Price  Year  Mileage               City State                Vin  \
# 0        8995  2014    35725            El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606   Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851            El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922            Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142             Lindon    UT  19UDE2F32GA001284
# 5        7989  2012   105246              Miami    FL  JH4CU2F83CC019895
# 6       14490  2014    34032          Greatneck    NY  JH4CU2F84EC002686
# 7       13995  2013    32384        West Jordan    UT  JH4CU2F64DC006203
# 8       10495  2013    57596          Waterbury    CT  19VDE2E50DE000234
# 9        9995  2013    63887            El Paso    TX  19VDE1F50DE010450
# 10      12921  2012    58550              Boise    ID  JH4CU2F44CC003220
# 11      12000  2013    40527   Long Island City    NY  19VDE1F38DE020867
# ...

# %%
df.to_csv('csv1.csv', index=False)
