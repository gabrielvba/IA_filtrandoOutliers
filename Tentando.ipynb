# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("true_car_listings.csv")

# %%
df.head()
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
df.isnull().sum()
# Out:
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %%
df.dtypes
# Out:
# Price       int64
# Year        int64
# Mileage     int64
# City       object
# State      object
# Vin        object
# Make       object
# Model      object
# dtype: object

# %%
df.describe()
# Out:
#                Price           Year       Mileage
# count  852122.000000  852122.000000  8.521220e+05
# mean    21464.100210    2013.289145  5.250779e+04
# std     13596.202241       3.414987  4.198896e+04
# min      1500.000000    1997.000000  5.000000e+00
# 25%     13000.000000    2012.000000  2.383600e+04
# 50%     18500.000000    2014.000000  4.025600e+04
# 75%     26995.000000    2016.000000  7.218600e+04
# max    499500.000000    2018.000000  2.856196e+06

# %%
outlier_price = ( df.quantile(0.75)["Price"] - df.quantile(0.25)["Price"] ) * 1.5
outlier_mileage = ( df.quantile(0.75)["Mileage"] - df.quantile(0.25)["Mileage"] ) * 1.5

# %%
outlier_price
# Out:
# 20992.5

# %%
outlier_mileage
# Out:
# 72525.0

# %%
df2 = df.drop(df[(df.Price > df.quantile(0.75)["Price"] + outlier_price)|(df.Price <  df.quantile(0.25)["Price"]- outlier_price)].index)
df2
# Out:
#         Price  Year  Mileage               City State                Vin  \
# 0        8995  2014    35725            El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606   Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851            El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922            Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142             Lindon    UT  19UDE2F32GA001284
# 5        7989  2012   105246              Miami    FL  JH4CU2F83CC019895
# 6       14490  2014    34032          Greatneck    NY  JH4CU2F84EC002686
# 7       13995  2013    32384        West Jordan    UT  JH4CU2F64DC006203
# 8       10495  2013    57596          Waterbury    CT  19VDE2E50DE000234
# 9        9995  2013    63887            El Paso    TX  19VDE1F50DE010450
# 10      12921  2012    58550              Boise    ID  JH4CU2F44CC003220
# 11      12000  2013    40527   Long Island City    NY  19VDE1F38DE020867
# 12       7750  2009    91980        San Antonio    TX  JH4CU26639C015787
# 13      17628  2015    13797              Fargo    ND  19VDE1F38FE001240
# 14      13999  2013    35035          Santa Ana    CA  JH4CU2F4XDC000369
# 15      14995  2014    23454       Hackettstown    NJ  19VDE1F31EE009243
# 852111  46500  2017        8        San Leandro    CA  YV140MEM3H1370217
# 852112  46530  2017       10        San Leandro    CA  YV140MEK7H1364709
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# 2       Acura    ILX6-Speed
# 3       Acura    ILX5-Speed
# 4       Acura  ILXAutomatic
# 5       Acura  TSXAutomatic
# 6       Acura    TSXSpecial
# 7       Acura    TSX5-Speed
# 8       Acura    ILX6-Speed
# 9       Acura    ILX5-Speed
# 10      Acura  TSXAutomatic
# 11      Acura    ILX5-Speed
# 12      Acura        TSX4dr
# 13      Acura    ILX5-Speed
# 14      Acura    TSX5-Speed
# 15      Acura    ILX5-Speed
# 16      Acura    ILX5-Speed
# 17      Acura        TSX4dr
# 18      Acura        TSX4dr
# 19      Acura        TSX4dr
# 20      Acura    ILX5-Speed
# 21      Acura    TSX5-Speed
# 22      Acura    ILX5-Speed
# 23      Acura    TSX5-Speed
# 24      Acura    ILX5-Speed
# 25      Acura    TSXSpecial
# 26      Acura        TSX4dr
# 27      Acura    ILX5-Speed
# 28      Acura    ILX5-Speed
# 29      Acura    ILX5-Speed
# ...       ...           ...
# 851997  Volvo       XC90AWD
# 851998  Volvo     S602015.5
# 852002  Volvo         V60T5
# 852005  Volvo        XC60T5
# 852010  Volvo        XC90T6
# 852011  Volvo        XC60T6
# 852012  Volvo        V705dr
# 852014  Volvo           V60
# 852015  Volvo       XC90AWD
# 852016  Volvo         S90T5
# 852017  Volvo        XC60T6
# 852019  Volvo       XC90AWD
# 852021  Volvo        XC60T6
# 852022  Volvo           V60
# 852023  Volvo        XC60T6
# 852024  Volvo         V60T5
# 852028  Volvo       XC60AWD
# 852029  Volvo           V60
# 852030  Volvo        XC60T6
# 852038  Volvo           V60
# 852043  Volvo         V60T6
# 852048  Volvo       XC70AWD
# 852051  Volvo        XC60T6
# 852052  Volvo        XC60T6
# 852070  Volvo        XC60T6
# 852076  Volvo         V60T6
# 852089  Volvo         S60T5
# 852108  Volvo         V60T5
# 852111  Volvo         V60T5
# 852112  Volvo         V60T5
#
# [824097 rows x 8 columns]

# %%
df3 = df.drop(df[(df.Price > df.quantile(0.75)["Mileage"] + outlier_mileage)|(df.Price <  df.quantile(0.25)["Mileage"]- outlier_mileage)].index)
df3
# Out:
#         Price  Year  Mileage               City State                Vin  \
# 0        8995  2014    35725            El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606   Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851            El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922            Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142             Lindon    UT  19UDE2F32GA001284
# 5        7989  2012   105246              Miami    FL  JH4CU2F83CC019895
# 6       14490  2014    34032          Greatneck    NY  JH4CU2F84EC002686
# 7       13995  2013    32384        West Jordan    UT  JH4CU2F64DC006203
# 8       10495  2013    57596          Waterbury    CT  19VDE2E50DE000234
# 9        9995  2013    63887            El Paso    TX  19VDE1F50DE010450
# 852114  53855  2017     7530           Marietta    GA  YV1A22MK3H1004002
# 852115  80895  2017       10       Corte Madera    CA  YV4BC0ZX0H1124188
# 852116  54995  2017     2474             Berwyn    PA  YV1A22MK1H1010445
# 852117  63215  2017        9        Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201          Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941       Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005        San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502           New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# 2       Acura    ILX6-Speed
# 3       Acura    ILX5-Speed
# 4       Acura  ILXAutomatic
# 5       Acura  TSXAutomatic
# 6       Acura    TSXSpecial
# 7       Acura    TSX5-Speed
# 8       Acura    ILX6-Speed
# 9       Acura    ILX5-Speed
# 10      Acura  TSXAutomatic
# 11      Acura    ILX5-Speed
# 12      Acura        TSX4dr
# 13      Acura    ILX5-Speed
# 14      Acura    TSX5-Speed
# 15      Acura    ILX5-Speed
# 16      Acura    ILX5-Speed
# 17      Acura        TSX4dr
# 18      Acura        TSX4dr
# 19      Acura        TSX4dr
# 20      Acura    ILX5-Speed
# 21      Acura    TSX5-Speed
# 22      Acura    ILX5-Speed
# 23      Acura    TSX5-Speed
# 24      Acura    ILX5-Speed
# 25      Acura    TSXSpecial
# 26      Acura        TSX4dr
# 27      Acura    ILX5-Speed
# 28      Acura    ILX5-Speed
# 29      Acura    ILX5-Speed
# ...       ...           ...
# 852092  Volvo         S90T6
# 852093  Volvo       XC90AWD
# 852094  Volvo       XC90AWD
# 852095  Volvo           V90
# 852096  Volvo        XC90T8
# 852097  Volvo        XC90T5
# 852098  Volvo       XC90AWD
# 852099  Volvo       XC90AWD
# 852100  Volvo        XC90T6
# 852101  Volvo         S90T6
# 852102  Volvo         S90T6
# 852103  Volvo         S90T6
# 852104  Volvo         S90T6
# 852105  Volvo        XC90T6
# 852106  Volvo           V90
# 852107  Volvo         S90T6
# 852108  Volvo         V60T5
# 852109  Volvo           V90
# 852110  Volvo          XC90
# 852111  Volvo         V60T5
# 852112  Volvo         V60T5
# 852113  Volvo        XC90T8
# 852114  Volvo         S90T6
# 852115  Volvo        XC90T8
# 852116  Volvo         S90T6
# 852117  Volvo         S90T6
# 852118  Volvo        XC90T6
# 852119  Volvo       XC90AWD
# 852120  Volvo           V90
# 852121  Volvo        XC90T8
#
# [851296 rows x 8 columns]

# %%
df = df.sort_values(['Make', 'Model',"Price"])
df

# %%
"df2.to_csv('Data_frame_SemOutliers.csv', index=False)"

# %%
"df3.to_csv('Data_frame_SemOutliers_mileage.csv', index=False)"

# %%
"df.to_csv('Data_frame_ordenado.csv', index=False)"

# %%
grupo = df.groupby(['Make','Model']).mean()["Price"]
grupo
# Out:
# Make   Model
# AM     General                                59934.210526
# Acura  CLAutomatic                             4492.666667
#        CLManual                                4493.000000
#        CLType-S                                5207.736842
#        ILX4dr                                 15490.000000
#        ILX5-Speed                             17214.413636
#        ILX6-Speed                             16240.052632
#        ILXAcuraWatch                          21908.142857
#        ILXAutomatic                           22464.898396
#        ILXHybrid                              16692.727273
#        ILXPremium                             24611.380952
#        ILXTechnology                          26896.954545
#        IntegraGS                               3746.500000
#        IntegraLS                               3879.666667
#        IntegraRS                               3997.000000
#        MDX3.5L                                48019.000000
#        MDX4WD                                 10867.395147
#        MDXACURA                               11975.000000
#        MDXAWD                                 26904.574617
#        MDXAdvance                             38900.000000
#        MDXBase                                22256.705882
#        MDXFWD                                 34391.130168
#        MDXSH-AWD                              41585.495828
#        MDXSport                               54515.000000
#        MDXwith                                24451.117647
#        NSXCoupe                              175328.600000
#        NSXManual                              86995.000000
#        RDX*1-OWNER*LTHR*ROOF*BACK-UP*TECH     11995.000000
#        RDX4WD                                 10411.587838
#        RDXAWD                                 26934.152657
#                                                  ...
# Volvo  XC70Platinum                           24888.000000
#        XC70T5                                 28076.500000
#        XC70T6                                 30882.571429
#        XC90                                   52001.384615
#        XC902.5L                                6879.892857
#        XC902.5T                                4990.000000
#        XC903.2                                23994.500000
#        XC903.2L                               20975.000000
#        XC904.4L                                8079.666667
#        XC904DR                                22888.000000
#        XC904dr                                 6102.144444
#        XC90AWD                                30053.289238
#        XC90FWD                                15266.398374
#        XC90LEATHER                            16595.000000
#        XC90Premier                            26982.000000
#        XC90R-Design                           18498.000000
#        XC90T5                                 48085.615385
#        XC90T6                                 52773.702381
#        XC90T8                                 68836.777778
# smart  fortwo                                  6859.344086
#        fortwo2dr                               6168.977778
#        fortwoCabriolet                        11343.333333
#        fortwoCoupe                             8171.652174
#        fortwoPassion                          12888.920000
#        fortwoPrime                            12472.730769
#        fortwoProxy                            18269.000000
#        fortwoPure                             13717.878788
#        fortwopassion                           7782.034091
#        fortwoprime                            14998.500000
#        fortwopure                              7266.431138
# Name: Price, Length: 2755, dtype: float64

# %%
res2 = df2.loc[df2['Price'] < df2.quantile(0.25)["Price"] - x].groupby('Model')

# %%
res.to_csv('res.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-f017dfe3931e> in <module>()
# ----> 1 res.to_csv('res.csv', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'to_csv' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
res2.to_csv('res2.csv', index=False)

# %%
df2 = df2.drop(df2[df2["Vin"] == df.Vin])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-c379b5e8d0fa> in <module>()
# ----> 1 df2 = df2.drop(df2[df2["Vin"] == df.Vin])
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1188
#    1189         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1190             raise ValueError("Can only compare identically-labeled "
#    1191                              "Series objects")
#    1192
#
# ValueError: Can only compare identically-labeled Series objects

# %%
df2 = df2.drop(df2[(df2.Price > df2.quantile(0.75)["Price"] + x)|(df2.Price <  df2.quantile(0.25)["Price"]- x)].index)
