# %%
import pandas as pd
import itertools as it
import collections as c
import matplotlib.pyplot as plt
x = pd.read_csv("./results.csv")

# %%
words = []
for text in x.text:
    pv = str(text).replace(",", "")
    pv = pv.replace(".","")
    pv = pv.replace("–","")
    pv = pv.replace(" nan ","")
    words += pv.split()

#contar frequencia de palavras
repetidos = c.Counter(words)

mtt = 0 #palavras que ocorreram 1000 ou mais vezes
once = 0 #palavras que ocorreram apenas uma vez

for i in repetidos.keys():
    k = repetidos[i]
    if(k >=1000):
        mtt+=1
    
    if(k == 1) :
        once += 1

# %%
total_documents = len(x.index)
total_word_occurrences = len(words)
vocabulary_size = len(set(words))
words_occurring_1000_or_more_times = mtt
words_occurring_once = once

# %%
#tabela 4.1
tabela1 = pd.Series([total_documents,total_word_occurrences,vocabulary_size,words_occurring_1000_or_more_times,words_occurring_once], 
                    index=["Total documents", "Total word occurrences", "Vocabulary size", "Words_occurring > 1000 times", "Words occurring once"])
tabela1
# Out:
# Total documents                    249
# Total word occurrences          213355
# Vocabulary size                  30355
# Words_occurring > 1000 times        23
# Words occurring once             17875
# dtype: int64

# %%
# preparando tabela 4.2

def aux3(a):
    return repetidos.get(a)

def aux4(a):
    return a/total_word_occurrences

def aux5(a):
    return a*probabilidade[a-1]

palavras = (sorted(repetidos.keys(), key=repetidos.get,reverse=True))
ocorrencias = [aux3(x) for x in palavras]
ranking = list(range(1,len(palavras)+1))
probabilidade = [aux4(y) for y in ocorrencias]
rp = [aux5(w) for w in ranking]

# %%
#tabela 4.2

df = pd.DataFrame({'Word' : (palavras[:50]),
                   'Freq' : (ocorrencias[:50]),
                   'r' : (ranking[:50]),
                   'Pr(%)': (probabilidade[:50]),
                    'r.Pr':(rp[:50])})
df
# Out:
#           Word   Freq   r     Pr(%)      r.Pr
# 0           de  10116   1  0.047414  0.047414
# 1          que   6495   2  0.030442  0.060884
# 2            a   6478   3  0.030363  0.091088
# 3            o   5454   4  0.025563  0.102252
# 4            e   5374   5  0.025188  0.125940
# 5           do   3436   6  0.016105  0.096628
# 6           em   3069   7  0.014384  0.100691
# 7           da   2998   8  0.014052  0.112414
# 8           um   2550   9  0.011952  0.107567
# 9         para   2213  10  0.010372  0.103724
# 10         uma   2100  11  0.009843  0.108270
# 11         com   2087  12  0.009782  0.117382
# 12         não   1720  13  0.008062  0.104802
# 13          os   1709  14  0.008010  0.112142
# 14          se   1677  15  0.007860  0.117902
# 15           é   1660  16  0.007780  0.124487
# 16          no   1581  17  0.007410  0.125973
# 17          na   1525  18  0.007148  0.128659
# 18          as   1251  19  0.005863  0.111406
# 19         por   1230  20  0.005765  0.115301
# 20        como   1212  21  0.005681  0.119294
# 21        mais   1170  22  0.005484  0.120644
# 22         dos   1057  23  0.004954  0.113946
# 23          ao    909  24  0.004261  0.102252
# 24           O    771  25  0.003614  0.090342
# 25         sua    761  26  0.003567  0.092737
# 26         das    705  27  0.003304  0.089218
# 27         foi    689  28  0.003229  0.090422
# 28           à    672  29  0.003150  0.091341
# 29         seu    655  30  0.003070  0.092100
# 30         mas    646  31  0.003028  0.093862
# 31           A    614  32  0.002878  0.092091
# 32        anos    555  33  0.002601  0.085843
# 33         ser    496  34  0.002325  0.079042
# 34          ou    491  35  0.002301  0.080547
# 35        pelo    463  36  0.002170  0.078123
# 36        pela    459  37  0.002151  0.079600
# 37      também    445  38  0.002086  0.079258
# 38         nos    429  39  0.002011  0.078419
# 39       sobre    416  40  0.001950  0.077992
# 40       muito    382  41  0.001790  0.073408
# 41       entre    379  42  0.001776  0.074608
# 42         são    370  43  0.001734  0.074571
# 43        está    365  44  0.001711  0.075274
# 44  presidente    355  45  0.001664  0.074875
# 45          já    353  46  0.001655  0.076108
# 46        isso    344  47  0.001612  0.075780
# 47   Bolsonaro    337  48  0.001580  0.075817
# 48      quando    326  49  0.001528  0.074871
# 49         ele    325  50  0.001523  0.076164

# %%
plt.plot((ranking),(probabilidade))
plt.ylabel('frequencia')
plt.xlabel("ranking")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
def aux6(n):
    return (1/((n+1)*n))    
def aux7(n):
    return n/sum(qtdPalavras)

r1 =  sorted(repetidos.values())
r = c.Counter(r1)
nOcorrencias = sorted(r)
qtdPalavras = [r.get(x) for x in nOcorrencias]
pp = [aux6(x) for x in nOcorrencias]   #proporção prevista
pr = [aux7(x) for x in qtdPalavras]    #proporção real


dfa = pd.DataFrame({'Number of Ocurrencies (n)' : nOcorrencias ,
                   'Predict proportions' : pp,
                   'Actual proportion' : pr,
                   'Actual Number of the words': qtdPalavras})

dfa
# Out:
#      Number of Ocurrencies (n)  Predict proportions  Actual proportion  \
# 0                            1         5.000000e-01           0.588865
# 1                            2         1.666667e-01           0.140076
# 2                            3         8.333333e-02           0.066513
# 3                            4         5.000000e-02           0.040092
# 4                            5         3.333333e-02           0.027211
# 5                            6         2.380952e-02           0.018547
# 6                            7         1.785714e-02           0.014495
# 7                            8         1.388889e-02           0.011431
# 8                            9         1.111111e-02           0.009455
# 9                           10         9.090909e-03           0.009158
# 10                          11         7.575758e-03           0.005831
# 11                          12         6.410256e-03           0.005930
# 12                          13         5.494505e-03           0.004513
# 13                          14         4.761905e-03           0.004316
# 14                          15         4.166667e-03           0.003228
# 15                          16         3.676471e-03           0.002833
# 16                          17         3.267974e-03           0.003294
# 17                          18         2.923977e-03           0.002438
